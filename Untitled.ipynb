# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
# !python pipeline.py --input "C:/Users/Sarbartha/Downloads/VisDrone2019-MOT-val/VisDrone2019-MOT-val/sequences/uav0000339_00001_v" --output "outputs/result.mp4"
# Out:
# [Detector] SAHI OFF â†’ fallback YOLO | Device: cpu
#
# [Pipeline] Device: cpu
# [Pipeline] Starting: C:/Users/Sarbartha/Downloads/VisDrone2019-MOT-val/VisDrone2019-MOT-val/sequences/uav0000339_00001_v
#
# Frame 30 | FPS 1.2 | Dets 20 | Tracks 17
# Frame 60 | FPS 1.2 | Dets 28 | Tracks 27
# Frame 90 | FPS 1.2 | Dets 25 | Tracks 26
# Frame 120 | FPS 1.2 | Dets 27 | Tracks 29
# Frame 150 | FPS 1.2 | Dets 26 | Tracks 30
# Frame 180 | FPS 1.2 | Dets 19 | Tracks 20
# Frame 210 | FPS 1.2 | Dets 19 | Tracks 22
# Frame 240 | FPS 1.2 | Dets 16 | Tracks 18
# Frame 270 | FPS 1.2 | Dets 15 | Tracks 15
#
# ========== RESULT ==========
# Frames: 275
# Avg FPS: 1.22
# Total detections: 5912
# Unique IDs: 32
# Saved: outputs/result.mp4
# ===========================

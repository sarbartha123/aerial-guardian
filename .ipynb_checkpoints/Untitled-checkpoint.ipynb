# %%
import sys
# !{sys.executable} -m pip install ultralytics opencv-python numpy scipy
# Out:
# ...
#   Using cached ultralytics-8.4.41-py3-none-any.whl.metadata (39 kB)
# ...
#   Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached ultralytics_thop-2.0.19-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl.metadata (59 kB)
# ...
# Using cached ultralytics-8.4.41-py3-none-any.whl (1.2 MB)
# Using cached opencv_python-4.13.0.92-cp37-abi3-win_amd64.whl (40.2 MB)
# Using cached numpy-2.0.2-cp39-cp39-win_amd64.whl (15.9 MB)
# ...
#    ---------------------------------------- 0.0/802.4 kB ? eta -:--:--
#    ---------------------------------------- 802.4/802.4 kB 11.5 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/44.5 MB ? eta -:--:--
#    ---- ----------------------------------- 5.0/44.5 MB 27.4 MB/s eta 0:00:02
#    --------- ------------------------------ 11.0/44.5 MB 27.5 MB/s eta 0:00:02
#    --------------- ------------------------ 17.0/44.5 MB 28.2 MB/s eta 0:00:01
# ...

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
print("OK")
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Sarbartha\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# OK

# %%
import sys
# !{sys.executable} import torch

print("Torch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA device count:", torch.cuda.device_count())

if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
# Out:
# Torch version: 2.6.0+cu124
# CUDA available: True
# CUDA device count: 1
# GPU name: NVIDIA GeForce RTX 4060 Ti

# %%
import sys
# !{sys.executable} -m pip install filterpy
# Out:
# ...
#   Using cached filterpy-1.4.5.zip (177 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for filterpy: filename=filterpy-1.4.5-py3-none-any.whl size=110628 sha256=4e2d585892d5f21dec1fb777d86e9fc75f7faf19b3288b637b97c9ffb5fa6e91
#   Stored in directory: c:\users\sarbartha\appdata\local\pip\cache\wheels\53\e6\de\a09ea01e923aaf88b9f8c7c44329e857b2c1a31901167e55e6
# Successfully built filterpy
# ...
#   DEPRECATION: Building 'filterpy' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'filterpy'. Discussion can be found at https://github.com/pypa/pip/issues/6334

# %%
from filterpy.kalman import KalmanFilter
print("OK")
# Out:
# OK

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"] = "TRUE"

# %%
# !python pipeline.py --input "C:/Users/Sarbartha/Downloads/VisDrone2019-MOT-val/VisDrone2019-MOT-val/sequences/uav0000339_00001_v" --output "outputs/result.mp4"
# Out:
# [Detector] Model: yolo26l.pt | Device: cpu | Slicing: True
#
# [Pipeline] Starting: C:/Users/Sarbartha/Downloads/VisDrone2019-MOT-val/VisDrone2019-MOT-val/sequences/uav0000339_00001_v
#   Resolution: 1904x1071 | Source FPS: 30.0
#   Output: outputs/result.mp4
# Traceback (most recent call last):
#   File "C:\Users\Sarbartha\Drone-Project\Drone-Project\pipeline.py", line 216, in <module>
#     main()
#     ~~~~^^
#   File "C:\Users\Sarbartha\Drone-Project\Drone-Project\pipeline.py", line 212, in main
#     run_pipeline(args)
#     ~~~~~~~~~~~~^^^^^^
#   File "C:\Users\Sarbartha\Drone-Project\Drone-Project\pipeline.py", line 141, in run_pipeline
#     tracks = tracker.update(
#         detections,
#         compensate_fn=compensator.compensate_boxes,
#     )
# TypeError: ByteTrackPlus.update() got an unexpected keyword argument 'compensate_fn'

# %%
# !python analyze_gt.py \
    --gt "C:/Users/Sarbartha/Downloads/VisDrone2019-MOT-val/VisDrone2019-MOT-val/annotations/uav0000339_00001_v.txt" \
    --seq "C:/Users/Sarbartha/Downloads/VisDrone2019-MOT-val/VisDrone2019-MOT-val/sequences/uav0000339_00001_v" \
    --output outputs/analysis
# Out:
# Traceback (most recent call last):
#   File "C:\Users\Sarbartha\Drone-Project\Drone-Project\analyze_gt.py", line 339, in <module>
#     main()
#     ~~~~^^
#   File "C:\Users\Sarbartha\Drone-Project\Drone-Project\analyze_gt.py", line 336, in main
#     run_analysis(args)
#     ~~~~~~~~~~~~^^^^^^
#   File "C:\Users\Sarbartha\Drone-Project\Drone-Project\analyze_gt.py", line 149, in run_analysis
#     tracks = tracker.update(dets, frame, compensate_fn=compensator.compensate_boxes)
# TypeError: ByteTracker.update() got multiple values for argument 'compensate_fn'
# [1] Loading ground truth...
#     GT frames: 275 | Unique GT person IDs: 34
#
# [2] Initializing pipeline...
#     Image files: 275
#
# [3] Running frame-by-frame analysis...
